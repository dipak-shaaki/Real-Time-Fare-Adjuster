# %% [markdown]
# ### Installing necessaryy libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !git init
# Out:
# Initialized empty Git repository in D:/Real-Time-Fare-Adjuster/.git/

# %%
# !git add fare-adjuster.ipynb

# %%
# !git commit -m "Add initial notebook"
# Out:
# [main (root-commit) 3e6dd45] Add initial notebook
#  1 file changed, 72 insertions(+)
#  create mode 100644 fare-adjuster.ipynb

# %%
# !git branch -M main

# %%
# !git remote add origin https://github.com/dipak-shaaki/Real-Time-Fare-Adjuster.git

# %%
# !git push origin main
# Out:
# To https://github.com/dipak-shaaki/Real-Time-Fare-Adjuster.git
#  * [new branch]      main -> main
